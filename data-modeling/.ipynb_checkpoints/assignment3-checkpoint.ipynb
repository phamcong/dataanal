# %%
import pandas as pd
from datetime import timedelta
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.style.use('ggplot') # Look Pretty

# %%
#
# INFO: This dataset has call records for 10 users tracked over the course of 3 years.
# Your job is to find out where the users likely live at!
def showandtell(title=None):
  if title != None: plt.savefig(title + ".png", bbox_inches='tight', dpi=300)
  plt.show()
  exit()

# %%
def clusterInfo(model):
  print ("Cluster Analysis Inertia: ", model.inertia_)
  print ('------------------------------------------')
  for i in range(len(model.cluster_centers_)):
    print ("\n  Cluster ", i)
    print ("    Centroid ", model.cluster_centers_[i])
    print ("    #Samples ", (model.labels_==i).sum()) # NumPy Power

# %%
# Find the cluster with the least # attached nodes
def clusterWithFewestSamples(model):
  # Ensure there's at least on cluster...
  minSamples = len(model.labels_)
  minCluster = 0
  for i in range(len(model.cluster_centers_)):
    if minSamples > (model.labels_==i).sum():
      minCluster = i
      minSamples = (model.labels_==i).sum()
  print ("\n  Cluster With Fewest Samples: ", minCluster)
  return (model.labels_==minCluster)

# %%
# Find the cluster with the least # attached nodes
def clusterWithMostSamples(model):
  # Ensure there's at least on cluster...
  maxSamples = 0
  maxCluster = 0
  for i in range(len(model.cluster_centers_)):
    if maxSamples < (model.labels_==i).sum():
      maxCluster = i
      maxSamples = (model.labels_==i).sum()
  print ("\n  Cluster With Most Samples: ", maxCluster)
  print ("\n  Cluster With Most Samples (location): ", model.cluster_centers_[maxCluster])
  return (model.labels_==maxCluster)

# %%
# Find the cluster with the least # attached nodes
def clustersNumberSamples(model):
  # Ensure there's at least on cluster...
  for i in range(len(model.cluster_centers_)):
    print('\n Cluster ' + str(i) + ': ' + ' has ' + str((model.labels_==i).sum()) + ' attached samples')

# %%
def doKMeans(data, clusters=0):
  #
  # TODO: Be sure to only feed in Lat and Lon coordinates to the KMeans algo, since none of the other
  # data is suitable for your purposes. Since both Lat and Lon are (approximately) on the same scale,
  # no feature scaling is required. Print out the centroid locations and add them onto your scatter
  # plot. Use a distinguishable marker and color.
  #
  # Hint: Make sure you fit ONLY the coordinates, and in the CORRECT order (lat first).
  # This is part of your domain expertise.
  #
    from sklearn.cluster import KMeans
    kmeans = KMeans(n_clusters=clusters)
    kmeans.fit(data)
    
    return kmeans

# %%
#
# TODO: Load up the dataset and take a peek at its head and dtypes.
# Convert the date using pd.to_datetime, and the time using pd.to_timedelta
#
df = pd.read_csv('Datasets/CDR.csv')
df.head(n=5)
# Out:
#            In         Out Direction    CallDate         CallTime  DOW  \
# 0  4638472273  2666307251  Incoming  2010-12-25  07:16:24.736813  Sat
# 1  4638472273  1755442610  Incoming  2010-12-25  21:18:30.053710  Sat
# 2  4638472273  5481755331  Incoming  2010-12-25  14:52:42.878016  Sat
# 3  4638472273  1755442610  Incoming  2010-12-25  16:02:09.001913  Sat
# 4  4638472273  2145623768  Incoming  2010-12-25  15:28:35.028554  Sat
#
#          Duration                               TowerID   TowerLat   TowerLon
# 0  0:02:41.741499  0db53dd3-eb9c-4344-abc5-c2d74ebc3eec  32.731611 -96.709417
# 1  0:02:47.108750  aeaf8b43-8034-44fe-833d-31854a75acbf  32.731722 -96.709500
# 2  0:04:35.356341  fadaa83f-6001-45fd-aa4a-17d6c6b7ec00  32.899944 -96.910389
# 3  0:02:23.498499  fadaa83f-6001-45fd-aa4a-17d6c6b7ec00  32.899944 -96.910389
# 4  0:03:54.692497  95d7920d-c3cd-4d20-a568-9a55800dc807  32.899944 -96.910389

# %%
df.CallDate = pd.to_datetime(df.CallDate, errors='coerce')
df.CallTime = pd.to_timedelta(df.CallTime, errors='coerce')
df.head(5)
# Out:
#            In         Out Direction   CallDate        CallTime  DOW  \
# 0  4638472273  2666307251  Incoming 2010-12-25 07:16:24.736813  Sat
# 1  4638472273  1755442610  Incoming 2010-12-25 21:18:30.053710  Sat
# 2  4638472273  5481755331  Incoming 2010-12-25 14:52:42.878016  Sat
# 3  4638472273  1755442610  Incoming 2010-12-25 16:02:09.001913  Sat
# 4  4638472273  2145623768  Incoming 2010-12-25 15:28:35.028554  Sat
#
#          Duration                               TowerID   TowerLat   TowerLon
# 0  0:02:41.741499  0db53dd3-eb9c-4344-abc5-c2d74ebc3eec  32.731611 -96.709417
# 1  0:02:47.108750  aeaf8b43-8034-44fe-833d-31854a75acbf  32.731722 -96.709500
# 2  0:04:35.356341  fadaa83f-6001-45fd-aa4a-17d6c6b7ec00  32.899944 -96.910389
# 3  0:02:23.498499  fadaa83f-6001-45fd-aa4a-17d6c6b7ec00  32.899944 -96.910389
# 4  0:03:54.692497  95d7920d-c3cd-4d20-a568-9a55800dc807  32.899944 -96.910389

# %%
#
# TODO: Get a distinct list of "In" phone numbers (users) and store the values in a
# regular python list.
# Hint: https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.tolist.html
#
in_numbers = df['In'].unique()

# %%
#
# INFO: The locations map above should be too "busy" to really wrap your head around. This
# is where domain expertise comes into play. Your intuition tells you that people are likely
# to behave differently on weekends:
#
# On Weekend:
#   1. People probably don't go into work
#   2. They probably sleep in late on Saturday
#   3. They probably run a bunch of random errands, since they couldn't during the week
#   4. They should be home, at least during the very late hours, e.g. 1-4 AM
#
# On Weekdays:
#   1. People probably are at work during normal working hours
#   2. They probably are at home in the early morning and during the late night
#   3. They probably spend time commuting between work and home everyday

# %%
# 
# TODO: Create a slice called user1 that filters to only include dataset records where the
# "In" feature (user phone number) is equal to the first number on your unique list above
df_user1 = df[df.In == in_numbers[0]]
df_user1
# Out:
#                In         Out Direction   CallDate        CallTime  DOW  \
# 0      4638472273  2666307251  Incoming 2010-12-25 07:16:24.736813  Sat
# 1      4638472273  1755442610  Incoming 2010-12-25 21:18:30.053710  Sat
# 2      4638472273  5481755331  Incoming 2010-12-25 14:52:42.878016  Sat
# 3      4638472273  1755442610  Incoming 2010-12-25 16:02:09.001913  Sat
# 4      4638472273  2145623768  Incoming 2010-12-25 15:28:35.028554  Sat
# 5      4638472273  2946222380  Incoming 2010-12-25 11:38:17.275327  Sat
# 6      4638472273  7841019020    Missed 2010-12-25 10:38:35.924232  Sat
# 71     4638472273  5912117253  Incoming 2010-12-26 14:34:27.530327  Sun
# 72     4638472273  2145623768  Incoming 2010-12-26 20:45:00.306964  Sun
# 73     4638472273  4551601645    Missed 2010-12-26 16:03:43.841914  Sun
# 74     4638472273  6250348072  Incoming 2010-12-26 18:30:28.968794  Sun
# 75     4638472273  8180005891  Incoming 2010-12-26 19:19:23.380844  Sun
# ...

# %%
#
# TODO: Alter your slice so that it includes only Weekday (Mon-Fri) values.
#
df_user1 = df_user1[df.DOW.isin(['Mon', 'Tue', 'Wen', 'Thu', 'Fri'])]
df_user1
# Out:
# /Users/cuongpham/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#                In         Out Direction   CallDate        CallTime  DOW  \
# 161    4638472273  5912117253    Missed 2010-12-27 18:41:14.639828  Mon
# 194    4638472273  4217121115  Incoming 2010-12-28 21:36:14.190286  Tue
# 195    4638472273  6022767590  Incoming 2010-12-28 19:57:19.501140  Tue
# 196    4638472273  5621270003  Incoming 2010-12-28 17:10:15.465881  Tue
# 197    4638472273  5481755331  Incoming 2010-12-28 16:20:11.532130  Tue
# 198    4638472273  7756914135  Incoming 2010-12-28 19:41:43.122708  Tue
# 199    4638472273  6150928001  Incoming 2010-12-28 18:05:51.247679  Tue
# 200    4638472273  8180005891  Incoming 2010-12-28 15:27:51.105337  Tue
# 201    4638472273  6022767590    Missed 2010-12-28 20:43:50.766312  Tue
# ...

# %%
#
# TODO: The idea is that the call was placed before 5pm. From Midnight-730a, the user is
# probably sleeping and won't call / wake up to take a call. There should be a brief time
# in the morning during their commute to work, then they'll spend the entire day at work.
# So the assumption is that most of the time is spent either at work, or in 2nd, at home.
#
df_user1 = df_user1[df.CallTime < '17:00:00']
len(df_user1)
# Out:
# /Users/cuongpham/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# 827

# %%
#
# TODO: Plot the Cell Towers the user connected to
#
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(df_user1.TowerLon, df_user1.TowerLat, c='g', marker='o', alpha=0.2)
ax.set_title('Weekdays Calls (<5pm)')

# %%
#
# INFO: Run K-Means with K=3 or K=4. There really should only be a two areas of concentration. If you
# notice multiple areas that are "hot" (multiple areas the usr spends a lot of time at that are FAR
# apart from one another), then increase K=5, with the goal being that all centroids except two will
# sweep up the annoying outliers and not-home, not-work travel occasions. the other two will zero in
# on the user's approximate home location and work locations. Or rather the location of the cell
# tower closest to them.....
data = df_user1[['TowerLat', 'TowerLon']]
model = doKMeans(data, 3)

# %%
midWayClusterIndices = clusterWithFewestSamples(model)
midWaySamples = df_user1[midWayClusterIndices]
print ("    Its Waypoint Time: ", midWaySamples.CallTime.mean())
# Out:
#   Cluster With Fewest Samples:  2
#     Its Waypoint Time:  0 days 07:51:11.512252

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(model.cluster_centers_[:,1], model.cluster_centers_[:,0], s=169, c='r', marker='x', alpha=0.8, linewidths=2)

# %%
# run model with K_means = 4
data = df_user1[['TowerLat', 'TowerLon']]
model = doKMeans(data, 4)

# Print CallTime mean
midWayClusterIndices = clusterWithFewestSamples(model)
midWaySamples = df_user1[midWayClusterIndices]
print ("Its Waypoint Time: ", midWaySamples.CallTime.mean())

# Plot centroids
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(model.cluster_centers_[:,1], model.cluster_centers_[:,0], s=169, c='r', marker='x', alpha=0.8, linewidths=2)
# Out:
#   Cluster With Fewest Samples:  0
# Its Waypoint Time:  0 days 07:45:34.119499

# %%
model.cluster_centers_
# Out:
# array([[ 32.84658662, -96.81903994],
#        [ 32.90021687, -96.90939091],
#        [ 32.73319121, -96.70825364],
#        [ 32.87346117, -96.85028651]])

# %%
clustersNumberSamples(model)
# Out:
#  Cluster 0:  has 34 attached samples
#
#  Cluster 1:  has 570 attached samples
#
#  Cluster 2:  has 160 attached samples
#
#  Cluster 3:  has 63 attached samples

# %%
a = clusterWithMostSamples(model)
# Out:
#   Cluster With Most Samples:  1
#
#   Cluster With Most Samples (location):  [ 32.90021687 -96.90939091]

# %%
#
# TODO: Repeat the above steps for all 10 individuals, being sure to record their approximate home
# locations. You might want to use a for-loop, unless you enjoy typing.
#
for number in in_numbers:
    print('Predict location of call in number: ' + str(number) + '\n')
    user = df[df['In'] == number]
    user.plot.scatter(x='TowerLon', y='TowerLat', c='gray', alpha=0.1, title='Call Locations')
    user = user[user.DOW.isin(['Mon', 'Tue', 'Wen', 'Thu', 'Fri'])]
    user = user[user['CallTime']<'17:00:00']
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(user.TowerLon,user.TowerLat, c='g', marker='o', alpha=0.2)
    ax.set_title('Weekdays Calls (<5am)')
    
    # run model with K_means = 4
    data = user[['TowerLat', 'TowerLon']]
    model = doKMeans(data, 4)

    # Print CallTime mean
    clusterWithMostSamples(model)
# Out:
# Predict location of call in number: 4638472273
#
#
#   Cluster With Most Samples:  2
#
#   Cluster With Most Samples (location):  [ 32.90021687 -96.90939091]
# Predict location of call in number: 1559410755
#
#
#   Cluster With Most Samples:  0
#
#   Cluster With Most Samples (location):  [ 32.69552893 -96.93523955]
# Predict location of call in number: 4931532174
#
#
#   Cluster With Most Samples:  2
#
#   Cluster With Most Samples (location):  [ 32.780278 -96.893333]
# Predict location of call in number: 2419930464
#
#
#   Cluster With Most Samples:  1
#
#   Cluster With Most Samples (location):  [ 32.85371602 -96.8472918 ]
# Predict location of call in number: 1884182865
#
#
#   Cluster With Most Samples:  0
#
#   Cluster With Most Samples (location):  [ 32.922722 -96.757194]
# Predict location of call in number: 3688089071
#
#
#   Cluster With Most Samples:  0
#
#   Cluster With Most Samples (location):  [ 32.81175286 -96.87022804]
# ...
